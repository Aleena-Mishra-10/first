# %% [markdown]
# <a href="https://colab.research.google.com/github/Aleena-Mishra-10/first/blob/master/A_ICLR_Crop_Disease.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
import os
import zipfile
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import shutil
from PIL import Image

# %%
with zipfile.ZipFile("/content/drive/My Drive/ICLR Computer Vision for Crop Disease/train.zip","r") as zip_ref:
    zip_ref.extractall()

# %%
healthy_wheat = ['train/healthy_wheat/' + i for i in sorted(os.listdir('train/healthy_wheat'))]
leaf_rust = ['train/leaf_rust/' + i for i in sorted(os.listdir('train/leaf_rust'))]
stem_rust = ['train/stem_rust/' + i for i in sorted(os.listdir('train/stem_rust'))]

# %%
d1=pd.DataFrame(healthy_wheat)
d1.shape
# Out:
# (142, 1)

# %%
print("initial shape or dimention of healthy wheat",len(healthy_wheat))
print("initial shape or dimention of leaf rust",len(leaf_rust))
print("initial shape or dimention of stem rust",len(stem_rust))
# Out:
# initial shape or dimention of healthy wheat 142
# initial shape or dimention of leaf rust 358
# initial shape or dimention of stem rust 376

# %%
img = np.array(Image.open(leaf_rust[1]))
print(img.shape)
plt.imshow(img)
# Out:
# (468, 673, 3)

# %%
img = np.array(Image.open(leaf_rust[2]))
print(img.shape)
plt.imshow(img)
# Out:
# (194, 259, 3)

# %%
img = np.array(Image.open(leaf_rust[3]))
print(img.shape)
plt.imshow(img)
# Out:
# (1031, 776, 3)

# %%
img = np.array(Image.open(leaf_rust[4]))
print(img.shape)
plt.imshow(img)
# Out:
# (1049, 2541, 3)

# %%
img = np.array(Image.open(healthy_wheat[1]))
print(img.shape)
plt.imshow(img)
# Out:
# (1836, 3264, 3)

# %%
img=np.array(Image.open(stem_rust[1]))
print(img.shape)
plt.imshow(img)
# Out:
# (2848, 4272, 3)

# %%
img=np.array(Image.open(stem_rust[2]))
print(img.shape)
plt.imshow(img)
# Out:
# (4272, 2848, 3)
