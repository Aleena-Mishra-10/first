# %% [markdown]
# <a href="https://colab.research.google.com/github/Aleena-Mishra-10/first/blob/master/A_ICLR_Crop_Disease.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
import os
import zipfile
import numpy as np
import matplotlib.pyplot as plt
import shutil
import math
from PIL import Image


import tensorflow as tf
from tensorflow.keras.utils import Sequence
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Conv2D, BatchNormalization, Add, Activation, Lambda, concatenate, MaxPooling2D, Flatten, Dense, GlobalAveragePooling2D
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
# Out:
# <p style="color: red;">
# The default version of TensorFlow in Colab will switch to TensorFlow 2.x on the 27th of March, 2020.<br>
# We recommend you <a href="https://www.tensorflow.org/guide/migrate" target="_blank">upgrade</a> now
# or ensure your notebook will continue to use TensorFlow 1.x via the <code>%tensorflow_version 1.x</code> magic:
# <a href="https://colab.research.google.com/notebooks/tensorflow_version.ipynb" target="_blank">more info</a>.</p>

# %%
with zipfile.ZipFile("/content/drive/My Drive/ICLR Computer Vision for Crop Disease/train.zip","r") as zip_ref:
    zip_ref.extractall()

# %%
healthy_wheat = ['train/healthy_wheat/' + i for i in sorted(os.listdir('train/healthy_wheat'))]
leaf_rust = ['train/leaf_rust/' + i for i in sorted(os.listdir('train/leaf_rust'))]
stem_rust = ['train/stem_rust/' + i for i in sorted(os.listdir('train/stem_rust'))]

# %%
print('No of samples in healthy_wheat',len(healthy_wheat))
print('No of samples in leaf_rust',len(leaf_rust))
print('No of samples in stem_rust',len(stem_rust))
# Out:
# No of samples in healthy_wheat 142
# No of samples in leaf_rust 358
# No of samples in stem_rust 376

# %%
img = np.array(Image.open(healthy_wheat[3]))
print(img.shape)
plt.imshow(img)
# Out:
# (3024, 4032, 3)

# %%
img = np.array(Image.open(leaf_rust[3]))
print(img.shape)
plt.imshow(img)
# Out:
# (1031, 776, 3)

# %%
img = np.array(Image.open(stem_rust[1]))
print(img.shape)
plt.imshow(img)
# Out:
# (2848, 4272, 3)

# %%
all_files = np.array(healthy_wheat + leaf_rust + stem_rust)
np.random.shuffle(all_files)
print(len(all_files))
# Out:
# 876

# %%
def read_image(file_loc, dim):
    img = Image.open(file_loc)
    img = img.resize(dim)
    img = np.array(img)
    return img

# %%
for c, i in enumerate(all_files):
  img = read_image(i, (256, 256))
  if len(img.shape) == 2:
    all_files = np.delete(all_files, c)

# %%
len(all_files)
# Out:
# 875

# %%
train_files = all_files[:500]
valid_files = all_files[500:]

# %%
from albumentations import Compose, Resize, Flip, Rotate, ShiftScaleRotate, RandomBrightnessContrast, CLAHE, RandomCrop

# %%
class Generator(Sequence):

    label = { 'leaf_rust' : np.array([1, 0, 0]), 
              'stem_rust' : np.array([0, 1, 0]), 
              'healthy_wheat': np.array([0, 0, 1])}

    def __init__(self, x_set, batch_size=1, img_dim=(256, 256),augment=True):
        self.x = x_set
        self.batch_size = batch_size
        self.img_dim = img_dim
        self.augment = augment
        self.aug = Compose([Resize(height=256, width=256, always_apply=True),
                            Flip(p=0.5),
                            Rotate(p=0.5),
                            ShiftScaleRotate(p=0.5),
                            RandomBrightnessContrast(p=0.5),
                            CLAHE(p=0.5)], p=0.9)

    def __len__(self):
        return math.ceil(len(self.x) / self.batch_size)

    def __getitem__(self, idx):
        batch = self.x[idx * self.batch_size:(idx + 1) * self.batch_size]

        batch_x = np.array([read_image(img_id, self.img_dim) for img_id in batch])
        batch_y = np.array([self.label[img_id.split('/')[1]] for img_id in batch])

        if self.augment is True:
            batch_x = [self.aug(image=i)['image'] for i in batch_x]

        if self.batch_size==1:
            batch_x = np.squeeze(batch_x, 0)
            batch_y = np.squeeze(batch_y, 0)

        return batch_x/255, batch_y/1.0

# %%
def train_generator():
    generator = Generator(train_files, img_dim=(256,256))
    return generator
def valid_generator():
    generator = Generator(valid_files, img_dim=(256,256))
    return generator

ds_train = tf.data.Dataset.from_generator(
    train_generator,
    output_types=(tf.float32, tf.float32),
    output_shapes=([256,256,3], [3,])
    ).batch(10).repeat()

ds_valid = tf.data.Dataset.from_generator(
    valid_generator,
    output_types=(tf.float32, tf.float32),
    output_shapes=([256,256,3], [3,])
    ).batch(10).repeat()

# %%
for i, j in ds_train:
  print(i.shape)
  print(j.shape)
  break
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-13-9b5399208785> in <module>()
# ----> 1 for i, j in ds_train:
#       2   print(i.shape)
#       3   print(j.shape)
#       4   break
#
# /tensorflow-1.15.0/python3.6/tensorflow_core/python/data/ops/dataset_ops.py in __iter__(self)
#    2032
#    2033   def __iter__(self):
# -> 2034     return iter(self._dataset)
#    2035
#    2036
#
# /tensorflow-1.15.0/python3.6/tensorflow_core/python/data/ops/dataset_ops.py in __iter__(self)
#     341       return iterator_ops.IteratorV2(self)
#     342     else:
# --> 343       raise RuntimeError("__iter__() is only supported inside of tf.function "
#     344                          "or when eager execution is enabled.")
#     345
#
# RuntimeError: __iter__() is only supported inside of tf.function or when eager execution is enabled.

# %%
IMG_SHAPE = (256,256,3)

base_model = tf.keras.applications.InceptionResNetV2(input_shape=IMG_SHAPE,
                                               include_top=False,
                                               weights='imagenet')

base_model.trainable = False

model = tf.keras.Sequential([
  base_model,
  GlobalAveragePooling2D(),
  Dense(3, activation='softmax')
])
# Out:
# WARNING:tensorflow:From /tensorflow-1.15.0/python3.6/tensorflow_core/python/ops/resource_variable_ops.py:1630: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# Downloading data from https://github.com/fchollet/deep-learning-models/releases/download/v0.7/inception_resnet_v2_weights_tf_dim_ordering_tf_kernels_notop.h5
# 219062272/219055592 [==============================] - 7s 0us/step

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# inception_resnet_v2 (Model)  (None, 6, 6, 1536)        54336736
# _________________________________________________________________
# global_average_pooling2d (Gl (None, 1536)              0
# _________________________________________________________________
# dense (Dense)                (None, 3)                 4611
# =================================================================
# Total params: 54,341,347
# Trainable params: 4,611
# Non-trainable params: 54,336,736
# _________________________________________________________________

# %%
earlystopping = EarlyStopping(
    monitor='val_loss',
    min_delta=0,
    patience=7,
    verbose=0,
    restore_best_weights=True)
reducelr = ReduceLROnPlateau(
    monitor='val_loss',
    factor=0.1,
    patience=3,
    verbose=0,
    min_delta=0.0001 )
callbacks = [earlystopping, reducelr]

# %%
model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.001),
              loss='categorical_crossentropy',
              metrics=['accuracy', 'categorical_crossentropy'])

# %%
train_steps = len(train_files)//10
valid_steps = len(valid_files)//10

history = model.fit(
ds_train,
steps_per_epoch=train_steps,
epochs=50,
validation_data = ds_valid,
validation_steps = valid_steps,
callbacks=callbacks,
verbose=1
)
# Out:
# Train on 50 steps, validate on 37 steps
# Epoch 1/50
# 50/50 [==============================] - 133s 3s/step - loss: 0.8386 - acc: 0.6420 - categorical_crossentropy: 0.8386 - val_loss: 0.9433 - val_acc: 0.5865 - val_categorical_crossentropy: 0.9433
# Epoch 2/50
# 50/50 [==============================] - 124s 2s/step - loss: 0.8227 - acc: 0.6580 - categorical_crossentropy: 0.8227 - val_loss: 0.9239 - val_acc: 0.6054 - val_categorical_crossentropy: 0.9239
# Epoch 3/50
# 50/50 [==============================] - 124s 2s/step - loss: 0.8139 - acc: 0.6320 - categorical_crossentropy: 0.8139 - val_loss: 0.9302 - val_acc: 0.6108 - val_categorical_crossentropy: 0.9302
# Epoch 4/50
# 50/50 [==============================] - 123s 2s/step - loss: 0.8232 - acc: 0.6400 - categorical_crossentropy: 0.8232 - val_loss: 0.9294 - val_acc: 0.6081 - val_categorical_crossentropy: 0.9294
# Epoch 5/50
# 50/50 [==============================] - 123s 2s/step - loss: 0.8209 - acc: 0.6380 - categorical_crossentropy: 0.8209 - val_loss: 0.9361 - val_acc: 0.6162 - val_categorical_crossentropy: 0.9361
# Epoch 6/50
# 50/50 [==============================] - 122s 2s/step - loss: 0.8281 - acc: 0.6100 - categorical_crossentropy: 0.8281 - val_loss: 0.9456 - val_acc: 0.5946 - val_categorical_crossentropy: 0.9456
# Epoch 7/50
# 50/50 [==============================] - 123s 2s/step - loss: 0.8195 - acc: 0.6300 - categorical_crossentropy: 0.8195 - val_loss: 0.9365 - val_acc: 0.6216 - val_categorical_crossentropy: 0.9365
# Epoch 8/50
# 50/50 [==============================] - 123s 2s/step - loss: 0.8062 - acc: 0.6580 - categorical_crossentropy: 0.8062 - val_loss: 0.9085 - val_acc: 0.5892 - val_categorical_crossentropy: 0.9085
# Epoch 9/50
# 50/50 [==============================] - 123s 2s/step - loss: 0.8214 - acc: 0.6440 - categorical_crossentropy: 0.8214 - val_loss: 0.9421 - val_acc: 0.6027 - val_categorical_crossentropy: 0.9421
# Epoch 10/50
# 50/50 [==============================] - 121s 2s/step - loss: 0.8093 - acc: 0.6380 - categorical_crossentropy: 0.8093 - val_loss: 0.9167 - val_acc: 0.6162 - val_categorical_crossentropy: 0.9167
# Epoch 11/50
# 50/50 [==============================] - 120s 2s/step - loss: 0.8185 - acc: 0.6300 - categorical_crossentropy: 0.8185 - val_loss: 0.9285 - val_acc: 0.6027 - val_categorical_crossentropy: 0.9285
# Epoch 12/50
# 50/50 [==============================] - 120s 2s/step - loss: 0.8079 - acc: 0.6500 - categorical_crossentropy: 0.8079 - val_loss: 0.9534 - val_acc: 0.6108 - val_categorical_crossentropy: 0.9534
# Epoch 13/50
# 50/50 [==============================] - 120s 2s/step - loss: 0.8090 - acc: 0.6440 - categorical_crossentropy: 0.8090 - val_loss: 0.9565 - val_acc: 0.5973 - val_categorical_crossentropy: 0.9565
# Epoch 14/50
# 50/50 [==============================] - 122s 2s/step - loss: 0.8196 - acc: 0.6580 - categorical_crossentropy: 0.8196 - val_loss: 0.9306 - val_acc: 0.6054 - val_categorical_crossentropy: 0.9306
# Epoch 15/50
# 50/50 [==============================] - 123s 2s/step - loss: 0.8176 - acc: 0.6480 - categorical_crossentropy: 0.8176 - val_loss: 0.9885 - val_acc: 0.5649 - val_categorical_crossentropy: 0.9885

# %%
IMG_SHAPE = (256,256,3)

base_model = tf.keras.applications.VGG19(input_shape=IMG_SHAPE,
                                               include_top=False,
                                               weights='imagenet')

base_model.trainable = False

model = tf.keras.Sequential([
  base_model,
  GlobalAveragePooling2D(),
  Dense(3, activation='softmax')
])
# Out:
# Downloading data from https://github.com/fchollet/deep-learning-models/releases/download/v0.1/vgg19_weights_tf_dim_ordering_tf_kernels_notop.h5
# 80142336/80134624 [==============================] - 3s 0us/step

# %%
earlystopping = EarlyStopping(
    monitor='val_loss',
    min_delta=0,
    patience=7,
    verbose=0,
    restore_best_weights=True)
reducelr = ReduceLROnPlateau(
    monitor='val_loss',
    factor=0.1,
    patience=3,
    verbose=0,
    min_delta=0.0001 )
callbacks = [earlystopping, reducelr]

# %%
model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.001),
              loss='categorical_crossentropy',
              metrics=['accuracy', 'categorical_crossentropy'])

# %%
train_steps = len(train_files)//10
valid_steps = len(valid_files)//10

history = model.fit(
ds_train,
steps_per_epoch=train_steps,
epochs=50,
validation_data = ds_valid,
validation_steps = valid_steps,
callbacks=callbacks,
verbose=1
)
# Out:
# Train on 50 steps, validate on 37 steps
# Epoch 1/50
# 50/50 [==============================] - 125s 3s/step - loss: 1.1017 - acc: 0.3620 - categorical_crossentropy: 1.1017 - val_loss: 1.0162 - val_acc: 0.4162 - val_categorical_crossentropy: 1.0162
# Epoch 2/50
# 50/50 [==============================] - 120s 2s/step - loss: 1.0098 - acc: 0.4060 - categorical_crossentropy: 1.0098 - val_loss: 0.9850 - val_acc: 0.4054 - val_categorical_crossentropy: 0.9850
# Epoch 3/50
# 50/50 [==============================] - 118s 2s/step - loss: 0.9763 - acc: 0.4560 - categorical_crossentropy: 0.9763 - val_loss: 0.9720 - val_acc: 0.4757 - val_categorical_crossentropy: 0.9720
# Epoch 4/50
# 50/50 [==============================] - 119s 2s/step - loss: 0.9579 - acc: 0.5140 - categorical_crossentropy: 0.9579 - val_loss: 0.9453 - val_acc: 0.5000 - val_categorical_crossentropy: 0.9453
# Epoch 5/50
# 50/50 [==============================] - 119s 2s/step - loss: 0.9376 - acc: 0.5300 - categorical_crossentropy: 0.9376 - val_loss: 0.9364 - val_acc: 0.5000 - val_categorical_crossentropy: 0.9364
# Epoch 6/50
# 50/50 [==============================] - 120s 2s/step - loss: 0.9300 - acc: 0.5300 - categorical_crossentropy: 0.9300 - val_loss: 0.9433 - val_acc: 0.4946 - val_categorical_crossentropy: 0.9433
# Epoch 7/50
# 50/50 [==============================] - 119s 2s/step - loss: 0.9201 - acc: 0.5440 - categorical_crossentropy: 0.9201 - val_loss: 0.9163 - val_acc: 0.5568 - val_categorical_crossentropy: 0.9163
# Epoch 8/50
# 50/50 [==============================] - 118s 2s/step - loss: 0.9084 - acc: 0.5520 - categorical_crossentropy: 0.9084 - val_loss: 0.9152 - val_acc: 0.5432 - val_categorical_crossentropy: 0.9152
# Epoch 9/50
# 50/50 [==============================] - 119s 2s/step - loss: 0.9042 - acc: 0.5500 - categorical_crossentropy: 0.9042 - val_loss: 0.9083 - val_acc: 0.5486 - val_categorical_crossentropy: 0.9083
# Epoch 10/50
# 50/50 [==============================] - 119s 2s/step - loss: 0.8867 - acc: 0.5620 - categorical_crossentropy: 0.8867 - val_loss: 0.9115 - val_acc: 0.5432 - val_categorical_crossentropy: 0.9115
# Epoch 11/50
# 50/50 [==============================] - 119s 2s/step - loss: 0.8816 - acc: 0.5620 - categorical_crossentropy: 0.8816 - val_loss: 0.9077 - val_acc: 0.5649 - val_categorical_crossentropy: 0.9077
# Epoch 12/50
# 50/50 [==============================] - 119s 2s/step - loss: 0.8712 - acc: 0.5700 - categorical_crossentropy: 0.8712 - val_loss: 0.8956 - val_acc: 0.5568 - val_categorical_crossentropy: 0.8956
# Epoch 13/50
# 50/50 [==============================] - 118s 2s/step - loss: 0.8770 - acc: 0.5640 - categorical_crossentropy: 0.8770 - val_loss: 0.8873 - val_acc: 0.5757 - val_categorical_crossentropy: 0.8873
# Epoch 14/50
# 50/50 [==============================] - 119s 2s/step - loss: 0.8575 - acc: 0.5900 - categorical_crossentropy: 0.8575 - val_loss: 0.8836 - val_acc: 0.5811 - val_categorical_crossentropy: 0.8836
# Epoch 15/50
# 50/50 [==============================] - 119s 2s/step - loss: 0.8497 - acc: 0.5780 - categorical_crossentropy: 0.8497 - val_loss: 0.8841 - val_acc: 0.5595 - val_categorical_crossentropy: 0.8841
# Epoch 16/50
# 50/50 [==============================] - 120s 2s/step - loss: 0.8480 - acc: 0.6100 - categorical_crossentropy: 0.8480 - val_loss: 0.8811 - val_acc: 0.5811 - val_categorical_crossentropy: 0.8811
# Epoch 17/50
# 50/50 [==============================] - 119s 2s/step - loss: 0.8377 - acc: 0.6060 - categorical_crossentropy: 0.8377 - val_loss: 0.8965 - val_acc: 0.5838 - val_categorical_crossentropy: 0.8965
# Epoch 18/50
# 50/50 [==============================] - 118s 2s/step - loss: 0.8411 - acc: 0.5880 - categorical_crossentropy: 0.8411 - val_loss: 0.8551 - val_acc: 0.5946 - val_categorical_crossentropy: 0.8551
# Epoch 19/50
# 50/50 [==============================] - 119s 2s/step - loss: 0.8394 - acc: 0.6140 - categorical_crossentropy: 0.8394 - val_loss: 0.8654 - val_acc: 0.5730 - val_categorical_crossentropy: 0.8654
# Epoch 20/50
# 50/50 [==============================] - 118s 2s/step - loss: 0.8230 - acc: 0.6200 - categorical_crossentropy: 0.8230 - val_loss: 0.8611 - val_acc: 0.5946 - val_categorical_crossentropy: 0.8611
# Epoch 21/50
# 50/50 [==============================] - 119s 2s/step - loss: 0.8225 - acc: 0.6240 - categorical_crossentropy: 0.8225 - val_loss: 0.8716 - val_acc: 0.5811 - val_categorical_crossentropy: 0.8716
# Epoch 22/50
# 50/50 [==============================] - 118s 2s/step - loss: 0.8112 - acc: 0.6340 - categorical_crossentropy: 0.8112 - val_loss: 0.8498 - val_acc: 0.6189 - val_categorical_crossentropy: 0.8498
# Epoch 23/50
# 50/50 [==============================] - 117s 2s/step - loss: 0.8155 - acc: 0.6520 - categorical_crossentropy: 0.8155 - val_loss: 0.8634 - val_acc: 0.5811 - val_categorical_crossentropy: 0.8634
# Epoch 24/50
# 50/50 [==============================] - 116s 2s/step - loss: 0.7967 - acc: 0.6620 - categorical_crossentropy: 0.7967 - val_loss: 0.8468 - val_acc: 0.5919 - val_categorical_crossentropy: 0.8468
# Epoch 25/50
# 50/50 [==============================] - 119s 2s/step - loss: 0.8022 - acc: 0.6400 - categorical_crossentropy: 0.8022 - val_loss: 0.8548 - val_acc: 0.5811 - val_categorical_crossentropy: 0.8548
# Epoch 26/50
# 50/50 [==============================] - 118s 2s/step - loss: 0.8036 - acc: 0.6580 - categorical_crossentropy: 0.8036 - val_loss: 0.8503 - val_acc: 0.6081 - val_categorical_crossentropy: 0.8503
# Epoch 27/50
# 50/50 [==============================] - 119s 2s/step - loss: 0.8141 - acc: 0.6340 - categorical_crossentropy: 0.8141 - val_loss: 0.8564 - val_acc: 0.6000 - val_categorical_crossentropy: 0.8564
# Epoch 28/50
# 50/50 [==============================] - 122s 2s/step - loss: 0.8031 - acc: 0.6440 - categorical_crossentropy: 0.8031 - val_loss: 0.8373 - val_acc: 0.5946 - val_categorical_crossentropy: 0.8373
# Epoch 29/50
# 50/50 [==============================] - 125s 2s/step - loss: 0.7960 - acc: 0.6380 - categorical_crossentropy: 0.7960 - val_loss: 0.8742 - val_acc: 0.5541 - val_categorical_crossentropy: 0.8742
# Epoch 30/50
# 50/50 [==============================] - 126s 3s/step - loss: 0.7954 - acc: 0.6500 - categorical_crossentropy: 0.7954 - val_loss: 0.8541 - val_acc: 0.5838 - val_categorical_crossentropy: 0.8541
# Epoch 31/50
# 50/50 [==============================] - 126s 3s/step - loss: 0.7911 - acc: 0.6560 - categorical_crossentropy: 0.7911 - val_loss: 0.8552 - val_acc: 0.5838 - val_categorical_crossentropy: 0.8552
# Epoch 32/50
# 50/50 [==============================] - 126s 3s/step - loss: 0.8009 - acc: 0.6480 - categorical_crossentropy: 0.8009 - val_loss: 0.8370 - val_acc: 0.6081 - val_categorical_crossentropy: 0.8370
# Epoch 33/50
# 50/50 [==============================] - 126s 3s/step - loss: 0.8101 - acc: 0.6560 - categorical_crossentropy: 0.8101 - val_loss: 0.8590 - val_acc: 0.5838 - val_categorical_crossentropy: 0.8590
# Epoch 34/50
# 50/50 [==============================] - 127s 3s/step - loss: 0.8044 - acc: 0.6240 - categorical_crossentropy: 0.8044 - val_loss: 0.8580 - val_acc: 0.5811 - val_categorical_crossentropy: 0.8580
# Epoch 35/50
# 50/50 [==============================] - 126s 3s/step - loss: 0.7985 - acc: 0.6360 - categorical_crossentropy: 0.7985 - val_loss: 0.8507 - val_acc: 0.5973 - val_categorical_crossentropy: 0.8507
# Epoch 36/50
# 50/50 [==============================] - 126s 3s/step - loss: 0.8103 - acc: 0.6440 - categorical_crossentropy: 0.8103 - val_loss: 0.8354 - val_acc: 0.6027 - val_categorical_crossentropy: 0.8354
# Epoch 37/50
# 50/50 [==============================] - 124s 2s/step - loss: 0.8134 - acc: 0.6460 - categorical_crossentropy: 0.8134 - val_loss: 0.8538 - val_acc: 0.5865 - val_categorical_crossentropy: 0.8538
# Epoch 38/50
# 50/50 [==============================] - 123s 2s/step - loss: 0.8047 - acc: 0.6440 - categorical_crossentropy: 0.8047 - val_loss: 0.8562 - val_acc: 0.5865 - val_categorical_crossentropy: 0.8562
# Epoch 39/50
# 50/50 [==============================] - 124s 2s/step - loss: 0.7978 - acc: 0.6620 - categorical_crossentropy: 0.7978 - val_loss: 0.8490 - val_acc: 0.6027 - val_categorical_crossentropy: 0.8490
# Epoch 40/50
# 50/50 [==============================] - 122s 2s/step - loss: 0.8042 - acc: 0.6380 - categorical_crossentropy: 0.8042 - val_loss: 0.8416 - val_acc: 0.5892 - val_categorical_crossentropy: 0.8416
# Epoch 41/50
# 50/50 [==============================] - 122s 2s/step - loss: 0.8059 - acc: 0.6500 - categorical_crossentropy: 0.8059 - val_loss: 0.8619 - val_acc: 0.5838 - val_categorical_crossentropy: 0.8619
# Epoch 42/50
# 50/50 [==============================] - 121s 2s/step - loss: 0.7954 - acc: 0.6660 - categorical_crossentropy: 0.7954 - val_loss: 0.8580 - val_acc: 0.5703 - val_categorical_crossentropy: 0.8580
# Epoch 43/50
# 50/50 [==============================] - 120s 2s/step - loss: 0.8030 - acc: 0.6400 - categorical_crossentropy: 0.8030 - val_loss: 0.8537 - val_acc: 0.5919 - val_categorical_crossentropy: 0.8537
